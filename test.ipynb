# %% [markdown]
# # Train YOLO11 on Google Colab T4
# This notebook installs Ultralytics, checks the GPU, verifies the dataset path, and starts training. If you are using Colab, make sure the repository is cloned into `/content/yolov11-experimental` or update the project root path below.

# %%
# %pip install -U ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.36 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
# !nvidia-smi
import torch
print("Python:", __import__("sys").version)
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Thu Apr  9 12:44:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# 1. 克隆代码到指定路径
# !git clone https://github.com yolov11-experimental

# 2. 进入目录（使用 %cd 确保路径在整个 notebook 中生效）
# %cd /content/yolov11-experimental

# %%
import os
repo_root = "/content/yolov11-experimental"
if os.path.exists(repo_root):
    # %cd {repo_root}
else:
    print(f"Repo root not found: {repo_root}")
    print("Current working directory:", os.getcwd())
# Out:
# Repo root not found: /content/yolov11-experimental
# Current working directory: /content

# %%
from pathlib import Path
data_yaml = Path("hs-cmu/data.yaml")
print("Dataset config:", data_yaml)
print("Exists:", data_yaml.exists())
if not data_yaml.exists():
    print("Dataset config not found. Upload the hs-cmu folder or clone the repo into Colab.")

# %%
# !yolo train model=ultralytics/cfg/models/11/reinforce_yaml/yolo11s-testing.yaml data=hs-cmu/data.yaml batch=52 epochs=100 imgsz=640 workers=0 device=0 pretrained=weights/yolo11s.pt cache=True

# %%
from pathlib import Path
runs = Path("runs/train")
print("runs/train exists:", runs.exists())
if runs.exists():
    print("Latest training outputs:")
    for path in sorted(runs.glob("**/*"))[:20]:
        print(path)
